// %% [markdown]
// ## 活性化関数のプロット

// %%
:dep plotters = { git = "https://github.com/38/plotters", features = ["evcxr", "all_series", "all_elements"] }
extern crate plotters;
use plotters::prelude::*;

// %%
let figure = evcxr_figure((640, 480), |root| {
    root.fill(&WHITE)?;
    let mut chart = ChartBuilder::on(&root)
        .caption("y=sidmoid(x)", ("Arial", 30).into_font())
        .margin(5)
        .x_label_area_size(30)
        .y_label_area_size(30)
        .build_cartesian_2d(-5f32..5f32, -0.1f32..1f32)?;

    chart.configure_mesh().draw()?;

    chart.draw_series(LineSeries::new(
        (-50..=50).map(|x| x as f32 / 10.0).map(|x| (x, 1.0 / (1.0 + (-x).exp()))),
        &RED,
    )).unwrap()
        .label("y = sigmoid(x)")
        .legend(|(x,y)| PathElement::new(vec![(x,y), (x + 20,y)], &RED));

    chart.configure_series_labels()
        .background_style(&WHITE.mix(0.8))
        .border_style(&BLACK)
        .draw()?;
    Ok(())
});
figure
// Out:
// <div style=""><svg width="640" height="480" viewBox="0 0 640 480" xmlns="http://www.w3.org/2000/svg">
// <rect x="0" y="0" width="640" height="480" opacity="1" fill="#FFFFFF" stroke="none"/>
// <text x="320" y="10" dy="0.76em" text-anchor="middle" font-family="Arial" font-size="24.193548387096776" opacity="1" fill="#000000">
// y=sidmoid(x)
// </text>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="35" y1="444" x2="35" y2="39"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="40" y1="444" x2="40" y2="39"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="46" y1="444" x2="46" y2="39"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="52" y1="444" x2="52" y2="39"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="58" y1="444" x2="58" y2="39"/>
// <line opacity="0.1" stroke="#000000" stroke-width="1" x1="64" y1="444" x2="64" y2="39"/>
// ...
